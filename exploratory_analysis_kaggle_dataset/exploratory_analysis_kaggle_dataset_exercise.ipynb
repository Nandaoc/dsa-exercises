# %% [markdown]
# # <font color='blue'>Data Science Academy - Python Fundamentos - Capítulo 9</font>
#
# ## Download: http://github.com/dsacademybr
#
# ## Mini-Projeto 2 - Análise Exploratória em Conjunto de Dados do Kaggle
#
# ## Análise 1

# %%
# Importando bibliotecas
import os
import subprocess
import stat
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
sns.set(style = "white")
# %matplotlib inline

# %%
# Dataset
clean_data_path = "dataset/autos.csv"
df = pd.read_csv(clean_data_path,encoding = "latin-1")

# %%
df.head()
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat     Offer
# 1  2016-03-23 10:58:45            A5_Sportback_2.7_Tdi  privat     Offer
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat     Offer
# 3  2016-03-17 16:54:04             GOLF_4_1_4__3TÃRER  privat     Offer
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat     Offer
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  ...  \
# 0    480   test       Other                1993    manuell        0  ...
# 1  18300   test       coupe                2011    manuell      190  ...
# 2   9800   test         suv                2004  automatik      163  ...
# 3   1500   test  kleinwagen                2001    manuell       75  ...
# 4   3600   test  kleinwagen                2008    manuell       69  ...
#
#   postalCode             lastSeen yearOfCreation yearCrawled monthOfCreation  \
# ...

# %%
df.isnull().sum(axis=0)
# Out:
# dateCrawled              0
# name                     0
# seller                   0
# offerType                0
# price                    0
# abtest                   0
# vehicleType              0
# yearOfRegistration       0
# gearbox                  0
# powerPS                  0
# model                    0
# kilometer                0
# monthOfRegistration      0
# fuelType               189
# brand                    0
# notRepairedDamage        0
# dateCreated              0
# postalCode               0
# lastSeen                 0
# yearOfCreation           0
# yearCrawled              0
# monthOfCreation          0
# monthCrawled             0
# NoOfDaysOnline           0
# NoOfHrsOnline            0
# yearsOld                 0
# monthsOld                0
# dtype: int64

# %%
df.shape
# Out:
# (313687, 27)

# %%
df.describe()
# Out:
#                price  yearOfRegistration        powerPS      kilometer  \
# count  313687.000000       313687.000000  313687.000000  313687.000000
# mean     3902.961863         2001.909231     109.564250  131435.778340
# std      4168.150636            6.803211     191.741685   34963.149957
# min         0.000000         1910.000000       0.000000    5000.000000
# 25%       999.000000         1998.000000      68.000000  125000.000000
# 50%      2490.000000         2002.000000     104.000000  150000.000000
# 75%      5400.000000         2006.000000     140.000000  150000.000000
# max     28800.000000         2016.000000   20000.000000  150000.000000
#
#           postalCode  yearOfCreation  yearCrawled  NoOfDaysOnline  \
# count  313687.000000   313687.000000     313687.0   313687.000000
# mean    50349.563597     2015.999930       2016.0        8.543274
# std     25765.545682        0.008374          0.0        8.511917
# ...

# %% [markdown]
# ## Distribuição de Veículos com base no Ano de Registro
#
# ### Exercício 1
#
# Crie um Plot com a Distribuição de Veículos com base no Ano de Registro.

# %%
# referência: https://stackoverflow.com/questions/14770735/how-do-i-change-the-figure-size-with-subplots
fig, ax = plt.subplots(figsize = (8,6))
plt.hist(df['yearOfRegistration'])
plt.ylabel("Densidade (KDE)")
plt.xlabel("Ano de Registro")
plt.title('Distribuição de Veículos com Base no Ano de Registro', fontdict = {'size': 14})
plt.show()

# %% [markdown]
# ## Variação da faixa de preço pelo tipo de veículo
#
# ### Exercício 2
#
# Crie um Boxplot para avaliar os outliers.

# %%
fig, ax = plt.subplots(figsize = (10,8))
sns.boxplot(x = 'vehicleType', y = 'price', data = df)
ax.xaxis.set_label_text('Tipo de Veículo',fontdict = {'size':14})
ax.yaxis.set_label_text('Range de Preço',fontdict = {'size':14})
ax.set_title('Variação da Faixa de Preço pelo Tipo de Veículo', fontdict = {'size': 16})
plt.show()

# %% [markdown]
# ## Contagem total de vaículos à venda conforme tipo de veículo
#
# ### Exercício 3
#
# Crie um `count plot` que mostre o número de vículos pertencentes a cada categoria

# %%
# referência: https://seaborn.pydata.org/generated/seaborn.countplot.html
fig, ax = plt.subplots(figsize = (10,8))
sns.countplot(x = 'vehicleType', data = df)
ax.xaxis.set_label_text('Tipo de Veículo',fontdict = {'size':16})
ax.yaxis.set_label_text('Total de Veículos Para Venda', fontdict = {'size':16})
ax.set_title('Contagem total de Veículos à venda Conforme o Tipo', fontdict = {'size': 16})
plt.show()

# %% [markdown]
# ## Número de veículos pertencentes a cada marca
#
# ### Exercício 4
#
# Crie um Plot que mostre o número de veículos pertencentes a cada marca.

# %%
fig, ax = plt.subplots(figsize = (10,8))
sns.countplot(y = 'brand', data = df)
ax.set_title('Número de Veículos Pertencentes a Cada Marca',fontdict = {'size':18})
ax.xaxis.set_label_text('Número de Veículos',fontdict = {'size':16})
ax.yaxis.set_label_text('Marca',fontdict = {'size':16})
plt.show()

# %% [markdown]
# ## Preço médio dos veículos com base no tipo de veículo, bem como no tipo de caixa de câmbio
#
# ### Exercício 5
#
# Crie um Plot com o Preço médio dos veículos com base no tipo de veículo, bem como no tipo de caixa de câmbio.

# %%
fig, ax = plt.subplots(figsize = (10,8))
sns.barplot(x = 'vehicleType', y = 'price', hue = 'gearbox', data = df)
ax.set_title('Preço Médio por Tipo de Vaículo e Caixa de Câmbio',fontdict = {'size':18})
ax.xaxis.set_label_text('Tipo de Veículo',fontdict = {'size':16})
ax.yaxis.set_label_text('Preço',fontdict = {'size':16})
plt.show()

# %% [markdown]
# ## Preço médio do veículo por tipo de combustível e tipo de caixa de câmbio
#
# ### Exercício 6
#
# Crie um `Barplot` com o Preço médio do veículo por tipo de combustível e tipo de caixa de câmbio.

# %%
fig, ax = plt.subplots(figsize = (8, 5))
sns.barplot(x = 'fuelType', y = 'price', hue = 'gearbox', data = df)
ax.set_title('Preço Médio por Tipo de Combustível e Caixa de Câmbio',fontdict = {'size':14})
ax.xaxis.set_label_text('Tipo de Combustível',fontdict = {'size':12})
ax.yaxis.set_label_text('Preço Médio',fontdict = {'size':12})
plt.show()
